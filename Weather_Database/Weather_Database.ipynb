# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a new set of 2,000 random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Get the nearest city using the citipy module
from citipy import citipy

# %%
# empty list for cities
cities = []
# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count
len(cities)
# Out:
# 746

# %%
# Perform an API call with the OpenWeatherMap
import requests

weather_api_key="7e90cc4bf2ce56e96ff5f11de066b35b"

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Retrieve the following information from the API call:

# Latitude and longitude
# Maximum temperature
# Percent humidity
# Percent cloudiness
# Wind speed
# Weather description (for example, clouds, fog, light rain, clear sky)

# empty list for city data
city_data = []

# logging header
print("Beginning Data Retrieval     ")
print("-----------------------------")

#initiate counters
record_count = 1
set_count = 1

# loop all cities
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities
    try:
# Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
# Parse out the needed data
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        # Append the city_data list
        city_data.append({"City": city.title(),
              "Country": city_country,
              "Lat": city_lat,
              "Lng": city_lng,
              "Max Temp": city_max_temp,
              "Humidity": city_humidity,
              "Cloudiness": city_clouds,
              "Wind Speed": city_wind,
              "Current Description": city_description})
        
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hermanus
# Processing Record 2 of Set 1 | puerto ayora
# Processing Record 3 of Set 1 | ozieri
# Processing Record 4 of Set 1 | saint-joseph
# Processing Record 5 of Set 1 | sonoita
# Processing Record 6 of Set 1 | hilo
# Processing Record 7 of Set 1 | kipushi
# Processing Record 8 of Set 1 | kalmunai
# Processing Record 9 of Set 1 | maturin
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | haines junction
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | victoria
# Processing Record 14 of Set 1 | khatanga
# Processing Record 15 of Set 1 | nikolskoye
# Processing Record 16 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 1 | hofn
# Processing Record 18 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 1 | tasiilaq
# Processing Record 20 of Set 1 | castro
# Processing Record 21 of Set 1 | cape town
# Processing Record 22 of Set 1 | new norfolk
# Processing Record 23 of Set 1 | shiyan
# Processing Record 24 of Set 1 | kasongo-lunda
# Processing Record 25 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 1 | havoysund
# Processing Record 27 of Set 1 | inderborskiy
# City not found. Skipping...
# Processing Record 28 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 1 | zheleznogorsk-ilimskiy
# Processing Record 30 of Set 1 | butaritari
# Processing Record 31 of Set 1 | montepuez
# Processing Record 32 of Set 1 | minsk mazowiecki
# Processing Record 33 of Set 1 | adrar
# Processing Record 34 of Set 1 | busselton
# Processing Record 35 of Set 1 | saint george
# Processing Record 36 of Set 1 | udachnyy
# Processing Record 37 of Set 1 | kapaa
# Processing Record 38 of Set 1 | hoquiam
# Processing Record 39 of Set 1 | tigzirt
# Processing Record 40 of Set 1 | georgetown
# Processing Record 41 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 42 of Set 1 | alta floresta
# Processing Record 43 of Set 1 | ponta do sol
# Processing Record 44 of Set 1 | lompoc
# Processing Record 45 of Set 1 | sorland
# Processing Record 46 of Set 1 | kuche
# City not found. Skipping...
# Processing Record 47 of Set 1 | atuona
# Processing Record 48 of Set 1 | hailar
# Processing Record 49 of Set 1 | kodiak
# Processing Record 50 of Set 1 | iskateley
# Processing Record 1 of Set 2 | anadyr
# Processing Record 2 of Set 2 | monte carmelo
# Processing Record 3 of Set 2 | longyearbyen
# Processing Record 4 of Set 2 | bredasdorp
# Processing Record 5 of Set 2 | jamestown
# Processing Record 6 of Set 2 | sainte-suzanne
# Processing Record 7 of Set 2 | kodinsk
# Processing Record 8 of Set 2 | sioux lookout
# Processing Record 9 of Set 2 | punta arenas
# Processing Record 10 of Set 2 | port alfred
# Processing Record 11 of Set 2 | pevek
# Processing Record 12 of Set 2 | albany
# Processing Record 13 of Set 2 | mecca
# Processing Record 14 of Set 2 | mananjary
# Processing Record 15 of Set 2 | tuktoyaktuk
# Processing Record 16 of Set 2 | bolshaya irba
# City not found. Skipping...
# Processing Record 17 of Set 2 | sao filipe
# Processing Record 18 of Set 2 | bethel
# Processing Record 19 of Set 2 | ulaangom
# Processing Record 20 of Set 2 | alto araguaia
# Processing Record 21 of Set 2 | bandipur
# Processing Record 22 of Set 2 | chuy
# Processing Record 23 of Set 2 | lebu
# Processing Record 24 of Set 2 | burica
# City not found. Skipping...
# Processing Record 25 of Set 2 | ancud
# Processing Record 26 of Set 2 | durusu
# Processing Record 27 of Set 2 | arraial do cabo
# Processing Record 28 of Set 2 | bukama
# Processing Record 29 of Set 2 | grindavik
# Processing Record 30 of Set 2 | mastic beach
# Processing Record 31 of Set 2 | aklavik
# Processing Record 32 of Set 2 | bubaque
# Processing Record 33 of Set 2 | salinas
# Processing Record 34 of Set 2 | batagay-alyta
# Processing Record 35 of Set 2 | barrow
# Processing Record 36 of Set 2 | aleksandrovskiy zavod
# Processing Record 37 of Set 2 | kavaratti
# Processing Record 38 of Set 2 | talnakh
# Processing Record 39 of Set 2 | san cristobal
# Processing Record 40 of Set 2 | port elizabeth
# Processing Record 41 of Set 2 | bambous virieux
# Processing Record 42 of Set 2 | ahipara
# Processing Record 43 of Set 2 | bluff
# Processing Record 44 of Set 2 | vaitape
# Processing Record 45 of Set 2 | whyalla
# Processing Record 46 of Set 2 | alofi
# Processing Record 47 of Set 2 | bone
# Processing Record 48 of Set 2 | san patricio
# Processing Record 49 of Set 2 | ilulissat
# Processing Record 50 of Set 2 | faanui
# Processing Record 1 of Set 3 | clyde river
# Processing Record 2 of Set 3 | geraldton
# Processing Record 3 of Set 3 | vaini
# Processing Record 4 of Set 3 | tukrah
# Processing Record 5 of Set 3 | cidreira
# Processing Record 6 of Set 3 | george town
# Processing Record 7 of Set 3 | puerto el triunfo
# Processing Record 8 of Set 3 | panaba
# Processing Record 9 of Set 3 | isangel
# Processing Record 10 of Set 3 | yeppoon
# Processing Record 11 of Set 3 | lasa
# Processing Record 12 of Set 3 | cruzeiro do sul
# Processing Record 13 of Set 3 | luanda
# Processing Record 14 of Set 3 | finschhafen
# Processing Record 15 of Set 3 | emerald
# Processing Record 16 of Set 3 | cherskiy
# Processing Record 17 of Set 3 | sovetskiy
# Processing Record 18 of Set 3 | port hardy
# Processing Record 19 of Set 3 | upernavik
# Processing Record 20 of Set 3 | yellowknife
# Processing Record 21 of Set 3 | laela
# Processing Record 22 of Set 3 | chapais
# Processing Record 23 of Set 3 | back mountain
# Processing Record 24 of Set 3 | grand gaube
# Processing Record 25 of Set 3 | sidney
# Processing Record 26 of Set 3 | nyurba
# Processing Record 27 of Set 3 | henties bay
# Processing Record 28 of Set 3 | hithadhoo
# Processing Record 29 of Set 3 | avaton
# Processing Record 30 of Set 3 | tateyama
# Processing Record 31 of Set 3 | tournefeuille
# Processing Record 32 of Set 3 | husavik
# Processing Record 33 of Set 3 | road town
# Processing Record 34 of Set 3 | constitucion
# Processing Record 35 of Set 3 | mataura
# Processing Record 36 of Set 3 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 37 of Set 3 | touros
# Processing Record 38 of Set 3 | omboue
# Processing Record 39 of Set 3 | thompson
# Processing Record 40 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 3 | port blair
# Processing Record 42 of Set 3 | sitka
# Processing Record 43 of Set 3 | kieta
# Processing Record 44 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 3 | saskylakh
# Processing Record 46 of Set 3 | tautira
# Processing Record 47 of Set 3 | neiafu
# Processing Record 48 of Set 3 | salalah
# Processing Record 49 of Set 3 | lagoa
# Processing Record 50 of Set 3 | tashla
# Processing Record 1 of Set 4 | namibe
# Processing Record 2 of Set 4 | avarua
# Processing Record 3 of Set 4 | chokurdakh
# Processing Record 4 of Set 4 | fairfield
# Processing Record 5 of Set 4 | rassvet
# Processing Record 6 of Set 4 | meridian
# Processing Record 7 of Set 4 | mahebourg
# Processing Record 8 of Set 4 | kruisfontein
# Processing Record 9 of Set 4 | abu zabad
# Processing Record 10 of Set 4 | bengkulu
# Processing Record 11 of Set 4 | qaanaaq
# Processing Record 12 of Set 4 | grants pass
# Processing Record 13 of Set 4 | campbell river
# Processing Record 14 of Set 4 | oranjemund
# Processing Record 15 of Set 4 | chardara
# Processing Record 16 of Set 4 | ustka
# Processing Record 17 of Set 4 | bilibino
# Processing Record 18 of Set 4 | marawi
# Processing Record 19 of Set 4 | east london
# Processing Record 20 of Set 4 | port lincoln
# Processing Record 21 of Set 4 | jiddah
# City not found. Skipping...
# Processing Record 22 of Set 4 | utiroa
# City not found. Skipping...
# Processing Record 23 of Set 4 | iqaluit
# Processing Record 24 of Set 4 | vao
# Processing Record 25 of Set 4 | iaciara
# Processing Record 26 of Set 4 | cabo san lucas
# Processing Record 27 of Set 4 | saint-philippe
# Processing Record 28 of Set 4 | provideniya
# Processing Record 29 of Set 4 | chumikan
# Processing Record 30 of Set 4 | brewster
# Processing Record 31 of Set 4 | bud
# Processing Record 32 of Set 4 | esperance
# Processing Record 33 of Set 4 | hobart
# Processing Record 34 of Set 4 | carahue
# Processing Record 35 of Set 4 | sylacauga
# Processing Record 36 of Set 4 | saint-louis
# Processing Record 37 of Set 4 | awassa
# Processing Record 38 of Set 4 | lerwick
# Processing Record 39 of Set 4 | cayenne
# Processing Record 40 of Set 4 | uruguaiana
# Processing Record 41 of Set 4 | dire
# Processing Record 42 of Set 4 | rundu
# Processing Record 43 of Set 4 | joshimath
# Processing Record 44 of Set 4 | severo-kurilsk
# Processing Record 45 of Set 4 | hambantota
# Processing Record 46 of Set 4 | boa vista
# Processing Record 47 of Set 4 | kahului
# Processing Record 48 of Set 4 | holovyne
# Processing Record 49 of Set 4 | bilma
# Processing Record 50 of Set 4 | tiksi
# Processing Record 1 of Set 5 | kang
# Processing Record 2 of Set 5 | dikson
# Processing Record 3 of Set 5 | najran
# Processing Record 4 of Set 5 | pervomayskoye
# Processing Record 5 of Set 5 | berlevag
# Processing Record 6 of Set 5 | yerofey pavlovich
# Processing Record 7 of Set 5 | beringovskiy
# Processing Record 8 of Set 5 | sao joao da barra
# Processing Record 9 of Set 5 | krasnoselkup
# Processing Record 10 of Set 5 | fortuna
# Processing Record 11 of Set 5 | san rafael
# Processing Record 12 of Set 5 | timmins
# Processing Record 13 of Set 5 | arrah
# Processing Record 14 of Set 5 | balashov
# Processing Record 15 of Set 5 | ambon
# Processing Record 16 of Set 5 | mullaitivu
# City not found. Skipping...
# Processing Record 17 of Set 5 | genhe
# Processing Record 18 of Set 5 | jinchang
# Processing Record 19 of Set 5 | avera
# Processing Record 20 of Set 5 | springbok
# Processing Record 21 of Set 5 | souillac
# Processing Record 22 of Set 5 | yemelyanovo
# Processing Record 23 of Set 5 | mar del plata
# Processing Record 24 of Set 5 | trairi
# Processing Record 25 of Set 5 | puerto colombia
# Processing Record 26 of Set 5 | yankton
# Processing Record 27 of Set 5 | tungkang
# City not found. Skipping...
# Processing Record 28 of Set 5 | sarangani
# Processing Record 29 of Set 5 | toumodi
# Processing Record 30 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 31 of Set 5 | kavieng
# Processing Record 32 of Set 5 | praia da vitoria
# Processing Record 33 of Set 5 | dicabisagan
# Processing Record 34 of Set 5 | andrelandia
# Processing Record 35 of Set 5 | tomatlan
# Processing Record 36 of Set 5 | biak
# Processing Record 37 of Set 5 | lorengau
# Processing Record 38 of Set 5 | harper
# Processing Record 39 of Set 5 | port arthur
# Processing Record 40 of Set 5 | vila velha
# Processing Record 41 of Set 5 | lodja
# Processing Record 42 of Set 5 | zarand
# Processing Record 43 of Set 5 | pisco
# Processing Record 44 of Set 5 | tidore
# City not found. Skipping...
# Processing Record 45 of Set 5 | yumbe
# Processing Record 46 of Set 5 | carnarvon
# Processing Record 47 of Set 5 | sapernoye
# Processing Record 48 of Set 5 | umm lajj
# Processing Record 49 of Set 5 | ituni
# City not found. Skipping...
# Processing Record 50 of Set 5 | satitoa
# City not found. Skipping...
# Processing Record 1 of Set 6 | kaitangata
# Processing Record 2 of Set 6 | tianpeng
# Processing Record 3 of Set 6 | nishihara
# Processing Record 4 of Set 6 | strezhevoy
# Processing Record 5 of Set 6 | mayo
# Processing Record 6 of Set 6 | eureka
# Processing Record 7 of Set 6 | big rapids
# Processing Record 8 of Set 6 | roald
# Processing Record 9 of Set 6 | quatre cocos
# Processing Record 10 of Set 6 | isiro
# Processing Record 11 of Set 6 | thinadhoo
# Processing Record 12 of Set 6 | nome
# Processing Record 13 of Set 6 | angoche
# Processing Record 14 of Set 6 | airai
# Processing Record 15 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 16 of Set 6 | fortuna foothills
# Processing Record 17 of Set 6 | ayia trias
# Processing Record 18 of Set 6 | nicolas bravo
# Processing Record 19 of Set 6 | jackson
# Processing Record 20 of Set 6 | tank
# Processing Record 21 of Set 6 | pryyutivka
# Processing Record 22 of Set 6 | torbay
# Processing Record 23 of Set 6 | brae
# Processing Record 24 of Set 6 | gasa
# Processing Record 25 of Set 6 | mutis
# Processing Record 26 of Set 6 | klaksvik
# Processing Record 27 of Set 6 | panguna
# Processing Record 28 of Set 6 | vigrestad
# Processing Record 29 of Set 6 | gurupi
# Processing Record 30 of Set 6 | aksum
# Processing Record 31 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 6 | porto novo
# Processing Record 33 of Set 6 | llandrindod wells
# Processing Record 34 of Set 6 | orlik
# Processing Record 35 of Set 6 | coquimbo
# Processing Record 36 of Set 6 | kocser
# Processing Record 37 of Set 6 | mehamn
# Processing Record 38 of Set 6 | sambava
# Processing Record 39 of Set 6 | flinders
# Processing Record 40 of Set 6 | vestmannaeyjar
# Processing Record 41 of Set 6 | liuzhou
# Processing Record 42 of Set 6 | dzhusaly
# City not found. Skipping...
# Processing Record 43 of Set 6 | nakamura
# Processing Record 44 of Set 6 | caibarien
# Processing Record 45 of Set 6 | ust-tsilma
# Processing Record 46 of Set 6 | okhotsk
# Processing Record 47 of Set 6 | stantsiya gorchakovo
# City not found. Skipping...
# Processing Record 48 of Set 6 | zouxian
# City not found. Skipping...
# Processing Record 49 of Set 6 | zabaykalsk
# Processing Record 50 of Set 6 | pilar
# Processing Record 1 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 2 of Set 7 | plettenberg bay
# Processing Record 3 of Set 7 | ballina
# Processing Record 4 of Set 7 | baturaja
# Processing Record 5 of Set 7 | atsiki
# City not found. Skipping...
# Processing Record 6 of Set 7 | port keats
# Processing Record 7 of Set 7 | puerto vallarta
# Processing Record 8 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 9 of Set 7 | samana
# Processing Record 10 of Set 7 | fort atkinson
# Processing Record 11 of Set 7 | carutapera
# Processing Record 12 of Set 7 | san jose
# Processing Record 13 of Set 7 | bara
# Processing Record 14 of Set 7 | marrakesh
# Processing Record 15 of Set 7 | tecoanapa
# Processing Record 16 of Set 7 | high rock
# Processing Record 17 of Set 7 | graneros
# Processing Record 18 of Set 7 | honningsvag
# Processing Record 19 of Set 7 | hami
# Processing Record 20 of Set 7 | neftekamsk
# Processing Record 21 of Set 7 | muravlenko
# Processing Record 22 of Set 7 | sinnamary
# Processing Record 23 of Set 7 | nantucket
# Processing Record 24 of Set 7 | mayumba
# Processing Record 25 of Set 7 | aasiaat
# Processing Record 26 of Set 7 | dwarka
# Processing Record 27 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 28 of Set 7 | oriximina
# Processing Record 29 of Set 7 | sorong
# Processing Record 30 of Set 7 | turukhansk
# Processing Record 31 of Set 7 | katsuura
# Processing Record 32 of Set 7 | manggar
# Processing Record 33 of Set 7 | necochea
# Processing Record 34 of Set 7 | dingle
# Processing Record 35 of Set 7 | bijar
# Processing Record 36 of Set 7 | khlong luang
# Processing Record 37 of Set 7 | abramovka
# Processing Record 38 of Set 7 | shakawe
# Processing Record 39 of Set 7 | kovdor
# Processing Record 40 of Set 7 | marshfield
# Processing Record 41 of Set 7 | borogontsy
# Processing Record 42 of Set 7 | nizhniy kuranakh
# Processing Record 43 of Set 7 | kropotkin
# Processing Record 44 of Set 7 | mwinilunga
# Processing Record 45 of Set 7 | mareeba
# Processing Record 46 of Set 7 | atasu
# Processing Record 47 of Set 7 | caucaia
# Processing Record 48 of Set 7 | buala
# Processing Record 49 of Set 7 | jumla
# Processing Record 50 of Set 7 | ketchikan
# Processing Record 1 of Set 8 | gat
# Processing Record 2 of Set 8 | tihemetsa
# Processing Record 3 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 4 of Set 8 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 8 | vostok
# Processing Record 6 of Set 8 | bruck an der leitha
# Processing Record 7 of Set 8 | lubango
# Processing Record 8 of Set 8 | valle de allende
# Processing Record 9 of Set 8 | agadir
# Processing Record 10 of Set 8 | udarnyy
# Processing Record 11 of Set 8 | pirovskoye
# Processing Record 12 of Set 8 | wanning
# Processing Record 13 of Set 8 | saint-pierre
# Processing Record 14 of Set 8 | maragogi
# Processing Record 15 of Set 8 | lavrentiya
# Processing Record 16 of Set 8 | college
# Processing Record 17 of Set 8 | fare
# Processing Record 18 of Set 8 | komsomolskiy
# Processing Record 19 of Set 8 | kadoma
# Processing Record 20 of Set 8 | det udom
# Processing Record 21 of Set 8 | salihorsk
# Processing Record 22 of Set 8 | axim
# Processing Record 23 of Set 8 | olafsvik
# Processing Record 24 of Set 8 | caucaguita
# Processing Record 25 of Set 8 | tufanganj
# Processing Record 26 of Set 8 | sept-iles
# Processing Record 27 of Set 8 | palmer
# Processing Record 28 of Set 8 | iracoubo
# Processing Record 29 of Set 8 | hualmay
# Processing Record 30 of Set 8 | fuzhou
# Processing Record 31 of Set 8 | belaya gora
# Processing Record 32 of Set 8 | sumbawa
# City not found. Skipping...
# Processing Record 33 of Set 8 | samarai
# Processing Record 34 of Set 8 | watertown
# Processing Record 35 of Set 8 | kutum
# Processing Record 36 of Set 8 | sampit
# Processing Record 37 of Set 8 | hamilton
# Processing Record 38 of Set 8 | parana
# Processing Record 39 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 8 | beidao
# Processing Record 41 of Set 8 | oeiras do para
# Processing Record 42 of Set 8 | lysyanka
# Processing Record 43 of Set 8 | staraya poltavka
# Processing Record 44 of Set 8 | cache creek
# Processing Record 45 of Set 8 | nemuro
# Processing Record 46 of Set 8 | luwuk
# Processing Record 47 of Set 8 | ullapool
# Processing Record 48 of Set 8 | ledyard
# Processing Record 49 of Set 8 | deputatskiy
# Processing Record 50 of Set 8 | butembo
# Processing Record 1 of Set 9 | segezha
# Processing Record 2 of Set 9 | loiza
# Processing Record 3 of Set 9 | laguna
# Processing Record 4 of Set 9 | zharkent
# Processing Record 5 of Set 9 | saint anthony
# Processing Record 6 of Set 9 | kathu
# Processing Record 7 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 8 of Set 9 | dehloran
# Processing Record 9 of Set 9 | siguiri
# Processing Record 10 of Set 9 | naze
# Processing Record 11 of Set 9 | ilhabela
# Processing Record 12 of Set 9 | la cruz
# Processing Record 13 of Set 9 | mayskiy
# Processing Record 14 of Set 9 | columbus
# Processing Record 15 of Set 9 | penukonda
# Processing Record 16 of Set 9 | bantry
# Processing Record 17 of Set 9 | saquena
# Processing Record 18 of Set 9 | snezhnogorsk
# Processing Record 19 of Set 9 | auki
# Processing Record 20 of Set 9 | kargasok
# Processing Record 21 of Set 9 | general cepeda
# Processing Record 22 of Set 9 | saldanha
# Processing Record 23 of Set 9 | dongsheng
# Processing Record 24 of Set 9 | bizhbulyak
# Processing Record 25 of Set 9 | bandarbeyla
# Processing Record 26 of Set 9 | la gomera
# Processing Record 27 of Set 9 | broome
# Processing Record 28 of Set 9 | menongue
# Processing Record 29 of Set 9 | aksay
# Processing Record 30 of Set 9 | tottori
# Processing Record 31 of Set 9 | gondanglegi
# Processing Record 32 of Set 9 | codrington
# Processing Record 33 of Set 9 | kingaroy
# Processing Record 34 of Set 9 | te anau
# Processing Record 35 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 36 of Set 9 | gualaco
# Processing Record 37 of Set 9 | manyana
# Processing Record 38 of Set 9 | zhezkazgan
# Processing Record 39 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 40 of Set 9 | atbasar
# Processing Record 41 of Set 9 | bathsheba
# Processing Record 42 of Set 9 | narsaq
# Processing Record 43 of Set 9 | iberia
# Processing Record 44 of Set 9 | xingyi
# Processing Record 45 of Set 9 | winnemucca
# Processing Record 46 of Set 9 | bachaquero
# Processing Record 47 of Set 9 | ribeira grande
# Processing Record 48 of Set 9 | turan
# Processing Record 49 of Set 9 | fonte boa
# Processing Record 50 of Set 9 | pandan
# Processing Record 1 of Set 10 | galiwinku
# City not found. Skipping...
# Processing Record 2 of Set 10 | paratinga
# Processing Record 3 of Set 10 | birin
# Processing Record 4 of Set 10 | north bend
# Processing Record 5 of Set 10 | lebanon
# Processing Record 6 of Set 10 | shenzhen
# Processing Record 7 of Set 10 | sola
# Processing Record 8 of Set 10 | karratha
# Processing Record 9 of Set 10 | nacozari
# Processing Record 10 of Set 10 | balykshi
# Processing Record 11 of Set 10 | revelstoke
# Processing Record 12 of Set 10 | hasaki
# Processing Record 13 of Set 10 | puerto madryn
# Processing Record 14 of Set 10 | jeremie
# Processing Record 15 of Set 10 | la ronge
# Processing Record 16 of Set 10 | trincomalee
# Processing Record 17 of Set 10 | dodge city
# Processing Record 18 of Set 10 | hong gai
# Processing Record 19 of Set 10 | darhan
# Processing Record 20 of Set 10 | ronne
# Processing Record 21 of Set 10 | ucluelet
# Processing Record 22 of Set 10 | catuday
# Processing Record 23 of Set 10 | show low
# Processing Record 24 of Set 10 | kualakapuas
# Processing Record 25 of Set 10 | sayabec
# City not found. Skipping...
# Processing Record 26 of Set 10 | nanortalik
# Processing Record 27 of Set 10 | nokaneng
# Processing Record 28 of Set 10 | wenling
# Processing Record 29 of Set 10 | ambilobe
# Processing Record 30 of Set 10 | yumen
# Processing Record 31 of Set 10 | cadillac
# Processing Record 32 of Set 10 | vardo
# Processing Record 33 of Set 10 | aktash
# Processing Record 34 of Set 10 | ulladulla
# Processing Record 35 of Set 10 | sanchursk
# Processing Record 36 of Set 10 | chepareria
# Processing Record 37 of Set 10 | qui nhon
# Processing Record 38 of Set 10 | ordu
# Processing Record 39 of Set 10 | altamira
# Processing Record 40 of Set 10 | ferrol
# Processing Record 41 of Set 10 | tabuk
# Processing Record 42 of Set 10 | latehar
# Processing Record 43 of Set 10 | port shepstone
# Processing Record 44 of Set 10 | leningradskiy
# Processing Record 45 of Set 10 | tanout
# Processing Record 46 of Set 10 | cap malheureux
# Processing Record 47 of Set 10 | morros
# Processing Record 48 of Set 10 | klyuchi
# Processing Record 49 of Set 10 | half moon bay
# Processing Record 50 of Set 10 | gariaband
# Processing Record 1 of Set 11 | gizo
# Processing Record 2 of Set 11 | tiarei
# Processing Record 3 of Set 11 | jiaocheng
# Processing Record 4 of Set 11 | lhokseumawe
# Processing Record 5 of Set 11 | saint-augustin
# Processing Record 6 of Set 11 | salinopolis
# Processing Record 7 of Set 11 | mozarlandia
# Processing Record 8 of Set 11 | warrington
# Processing Record 9 of Set 11 | turtkul
# City not found. Skipping...
# Processing Record 10 of Set 11 | mamallapuram
# Processing Record 11 of Set 11 | rorvik
# Processing Record 12 of Set 11 | san antonio
# Processing Record 13 of Set 11 | nosy varika
# Processing Record 14 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 11 | itoman
# Processing Record 16 of Set 11 | samandag
# Processing Record 17 of Set 11 | benguela
# Processing Record 18 of Set 11 | wasilla
# Processing Record 19 of Set 11 | batetskiy
# Processing Record 20 of Set 11 | egvekinot
# Processing Record 21 of Set 11 | vila
# Processing Record 22 of Set 11 | maniitsoq
# Processing Record 23 of Set 11 | uruzgan
# Processing Record 24 of Set 11 | zhifang
# Processing Record 25 of Set 11 | nizhniy tsasuchey
# Processing Record 26 of Set 11 | rawson
# Processing Record 27 of Set 11 | shache
# Processing Record 28 of Set 11 | madang
# Processing Record 29 of Set 11 | druzhba
# Processing Record 30 of Set 11 | moisakula
# Processing Record 31 of Set 11 | bisho
# Processing Record 32 of Set 11 | pedana
# Processing Record 33 of Set 11 | aden
# Processing Record 34 of Set 11 | matveyev kurgan
# Processing Record 35 of Set 11 | mhlume
# Processing Record 36 of Set 11 | ust-kulom
# Processing Record 37 of Set 11 | inhambane
# Processing Record 38 of Set 11 | dukat
# Processing Record 39 of Set 11 | norman wells
# Processing Record 40 of Set 11 | zabid
# Processing Record 41 of Set 11 | texarkana
# Processing Record 42 of Set 11 | sarakhs
# Processing Record 43 of Set 11 | le locle
# Processing Record 44 of Set 11 | abu samrah
# Processing Record 45 of Set 11 | richards bay
# Processing Record 46 of Set 11 | botwood
# Processing Record 47 of Set 11 | dolores
# Processing Record 48 of Set 11 | monaghan
# Processing Record 49 of Set 11 | bonthe
# Processing Record 50 of Set 11 | watsa
# Processing Record 1 of Set 12 | takoradi
# Processing Record 2 of Set 12 | odweyne
# Processing Record 3 of Set 12 | kjollefjord
# Processing Record 4 of Set 12 | portland
# Processing Record 5 of Set 12 | maunabo
# Processing Record 6 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 7 of Set 12 | sosnovo-ozerskoye
# Processing Record 8 of Set 12 | antofagasta
# Processing Record 9 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 12 | samsun
# Processing Record 11 of Set 12 | zeya
# Processing Record 12 of Set 12 | purranque
# Processing Record 13 of Set 12 | margate
# Processing Record 14 of Set 12 | do gonbadan
# Processing Record 15 of Set 12 | kaeo
# Processing Record 16 of Set 12 | liptovsky hradok
# Processing Record 17 of Set 12 | kashi
# Processing Record 18 of Set 12 | faya
# Processing Record 19 of Set 12 | tonk
# Processing Record 20 of Set 12 | iturama
# Processing Record 21 of Set 12 | goderich
# Processing Record 22 of Set 12 | ypsonas
# Processing Record 23 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 24 of Set 12 | washington
# Processing Record 25 of Set 12 | choctaw
# Processing Record 26 of Set 12 | mount isa
# Processing Record 27 of Set 12 | pese
# Processing Record 28 of Set 12 | otane
# Processing Record 29 of Set 12 | ayan
# Processing Record 30 of Set 12 | shunyi
# Processing Record 31 of Set 12 | conakry
# Processing Record 32 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 33 of Set 12 | ukiah
# Processing Record 34 of Set 12 | buraydah
# Processing Record 35 of Set 12 | linxia
# Processing Record 36 of Set 12 | kristiinankaupunki
# Processing Record 37 of Set 12 | arona
# Processing Record 38 of Set 12 | murwara
# Processing Record 39 of Set 12 | moose factory
# Processing Record 40 of Set 12 | beni mazar
# Processing Record 41 of Set 12 | luderitz
# Processing Record 42 of Set 12 | crestview
# Processing Record 43 of Set 12 | shitkino
# Processing Record 44 of Set 12 | shelburne
# Processing Record 45 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 46 of Set 12 | tabou
# Processing Record 47 of Set 12 | zakamensk
# Processing Record 48 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 12 | bestobe
# Processing Record 50 of Set 12 | ponta delgada
# Processing Record 1 of Set 13 | kalat
# Processing Record 2 of Set 13 | minna
# Processing Record 3 of Set 13 | taoudenni
# Processing Record 4 of Set 13 | mont-dore
# Processing Record 5 of Set 13 | kharan
# Processing Record 6 of Set 13 | cairns
# Processing Record 7 of Set 13 | rio grande
# Processing Record 8 of Set 13 | paslek
# Processing Record 9 of Set 13 | san vicente
# Processing Record 10 of Set 13 | karatu
# Processing Record 11 of Set 13 | shakhovskaya
# Processing Record 12 of Set 13 | ulagan
# Processing Record 13 of Set 13 | cheyenne
# Processing Record 14 of Set 13 | sisimiut
# Processing Record 15 of Set 13 | taunggyi
# Processing Record 16 of Set 13 | tromso
# Processing Record 17 of Set 13 | salina
# Processing Record 18 of Set 13 | kuybyshevo
# Processing Record 19 of Set 13 | pleasanton
# Processing Record 20 of Set 13 | ternate
# Processing Record 21 of Set 13 | yar-sale
# Processing Record 22 of Set 13 | ngunguru
# Processing Record 23 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 13 | broken hill
# Processing Record 25 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 26 of Set 13 | ereymentau
# Processing Record 27 of Set 13 | srednekolymsk
# Processing Record 28 of Set 13 | kushima
# Processing Record 29 of Set 13 | kosh-agach
# Processing Record 30 of Set 13 | tutoia
# Processing Record 31 of Set 13 | san luis
# Processing Record 32 of Set 13 | karamea
# City not found. Skipping...
# Processing Record 33 of Set 13 | porto empedocle
# Processing Record 34 of Set 13 | ostrovnoy
# Processing Record 35 of Set 13 | hat yai
# Processing Record 36 of Set 13 | elkton
# Processing Record 37 of Set 13 | lata
# Processing Record 38 of Set 13 | san rafael del sur
# Processing Record 39 of Set 13 | high level
# Processing Record 40 of Set 13 | santo antonio de padua
# Processing Record 41 of Set 13 | turtas
# Processing Record 42 of Set 13 | bria
# Processing Record 43 of Set 13 | akureyri
# Processing Record 44 of Set 13 | tabon
# Processing Record 45 of Set 13 | merauke
# Processing Record 46 of Set 13 | basco
# Processing Record 47 of Set 13 | juba
# Processing Record 48 of Set 13 | kirakira
# Processing Record 49 of Set 13 | conceicao do araguaia
# Processing Record 50 of Set 13 | kabare
# Processing Record 1 of Set 14 | korla
# Processing Record 2 of Set 14 | pemba
# Processing Record 3 of Set 14 | solovetskiy
# City not found. Skipping...
# Processing Record 4 of Set 14 | weligama
# Processing Record 5 of Set 14 | hailun
# Processing Record 6 of Set 14 | dingzhou
# Processing Record 7 of Set 14 | benicarlo
# Processing Record 8 of Set 14 | sao joao do paraiso
# Processing Record 9 of Set 14 | amurzet
# Processing Record 10 of Set 14 | los llanos de aridane
# Processing Record 11 of Set 14 | wuwei
# Processing Record 12 of Set 14 | cordoba
# Processing Record 13 of Set 14 | miragoane
# Processing Record 14 of Set 14 | barbar
# City not found. Skipping...
# Processing Record 15 of Set 14 | la orilla
# Processing Record 16 of Set 14 | padang
# Processing Record 17 of Set 14 | san-pedro
# Processing Record 18 of Set 14 | gwadar
# Processing Record 19 of Set 14 | kautokeino
# Processing Record 20 of Set 14 | pangnirtung
# Processing Record 21 of Set 14 | soe
# Processing Record 22 of Set 14 | kangaatsiaq
# Processing Record 23 of Set 14 | dickson
# Processing Record 24 of Set 14 | tura
# Processing Record 25 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 26 of Set 14 | salym
# Processing Record 27 of Set 14 | otradnoye
# Processing Record 28 of Set 14 | piacabucu
# Processing Record 29 of Set 14 | benemerito de las americas
# Processing Record 30 of Set 14 | bonavista
# Processing Record 31 of Set 14 | bloemfontein
# Processing Record 32 of Set 14 | yarada
# Processing Record 33 of Set 14 | coihaique
# Processing Record 34 of Set 14 | chicama
# Processing Record 35 of Set 14 | malkerns
# Processing Record 36 of Set 14 | bereda
# Processing Record 37 of Set 14 | kendari
# Processing Record 38 of Set 14 | georgiyevskoye
# Processing Record 39 of Set 14 | meulaboh
# Processing Record 40 of Set 14 | kholodnyy
# Processing Record 41 of Set 14 | tabory
# Processing Record 42 of Set 14 | sawtell
# Processing Record 43 of Set 14 | bartica
# Processing Record 44 of Set 14 | zhangye
# Processing Record 45 of Set 14 | santa maria del oro
# Processing Record 46 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 47 of Set 14 | vicuna
# Processing Record 48 of Set 14 | sucua
# Processing Record 49 of Set 14 | west odessa
# Processing Record 50 of Set 14 | beloha
# Processing Record 1 of Set 15 | kaihua
# Processing Record 2 of Set 15 | anjangaon
# Processing Record 3 of Set 15 | fort nelson
# Processing Record 4 of Set 15 | tshikapa
# Processing Record 5 of Set 15 | igrim
# Processing Record 6 of Set 15 | ballyshannon
# Processing Record 7 of Set 15 | palu
# Processing Record 8 of Set 15 | phumi samraong
# City not found. Skipping...
# Processing Record 9 of Set 15 | yulara
# Processing Record 10 of Set 15 | samalaeulu
# City not found. Skipping...
# Processing Record 11 of Set 15 | pemangkat
# Processing Record 12 of Set 15 | salta
# Processing Record 13 of Set 15 | joao pinheiro
# Processing Record 14 of Set 15 | pasni
# Processing Record 15 of Set 15 | shestakovo
# Processing Record 16 of Set 15 | huarmey
# Processing Record 17 of Set 15 | mazagao
# Processing Record 18 of Set 15 | wanaka
# Processing Record 19 of Set 15 | las vegas
# Processing Record 20 of Set 15 | tawnat
# City not found. Skipping...
# Processing Record 21 of Set 15 | polunochnoye
# Processing Record 22 of Set 15 | misratah
# Processing Record 23 of Set 15 | goure
# Processing Record 24 of Set 15 | sao felix do xingu
# Processing Record 25 of Set 15 | cockburn town
# Processing Record 26 of Set 15 | aswan
# Processing Record 27 of Set 15 | surt
# Processing Record 28 of Set 15 | nanning
# Processing Record 29 of Set 15 | ambodifototra
# City not found. Skipping...
# Processing Record 30 of Set 15 | badiraguato
# Processing Record 31 of Set 15 | mingaora
# Processing Record 32 of Set 15 | santa isabel do rio negro
# Processing Record 33 of Set 15 | dunmore east
# Processing Record 34 of Set 15 | dudinka
# Processing Record 35 of Set 15 | uni
# Processing Record 36 of Set 15 | kafanchan
# Processing Record 37 of Set 15 | magadan
# Processing Record 38 of Set 15 | namatanai
# Processing Record 39 of Set 15 | son la
# Processing Record 40 of Set 15 | babol
# Processing Record 41 of Set 15 | vaitupu
# City not found. Skipping...
# Processing Record 42 of Set 15 | ekibastuz
# Processing Record 43 of Set 15 | aberdeen
# Processing Record 44 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 45 of Set 15 | kerteh
# City not found. Skipping...
# Processing Record 46 of Set 15 | ruatoria
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# add the data to a dataframe
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Hermanus      ZA -34.4187   19.2345     63.12        90          99
# 1  Puerto Ayora      EC  -0.7393  -90.3518     76.77        88          92
# 2        Ozieri      IT  40.5860    9.0012     46.76        96         100
# 3  Saint-Joseph      RE -21.3667   55.6167     75.58        84          83
# 4       Sonoita      MX  31.8500 -112.8333     61.38        11           0
#
#    Wind Speed Current Description
# 0        3.31     overcast clouds
# 1        5.77     overcast clouds
# 2        5.10     overcast clouds
# 3       16.02          light rain
# 4       11.16           clear sky

# %%
# Create the output csv
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
#export DF to output file
city_data_df.to_csv(output_data_file, index_label="City_ID")
